# %% [markdown]
# ### Data Analysis

# %%
# import all the libraries needed for analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
plt.style.use('ggplot')

# %%
# this data has duplications because of language seperated and added as rows
df = pd.read_csv('zocdocnyc_cleaned.csv', index_col = 0)

# %%
df0 = df.loc[df['Level'] == 0] # only picked the first row for every level

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4000 entries, Dr. Rita Aronov, MD to Rachel Freed, PhD
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Level            4000 non-null   int64
#  1   Specialties      4000 non-null   object
#  2   Gender           4000 non-null   object
#  3   Language         3972 non-null   object
#  4   Video_Visit      4000 non-null   bool
#  5   City             4000 non-null   object
#  6   Zipcode          3520 non-null   float64
#  7   Total_Reviews    3292 non-null   float64
#  8   Overall_Ratings  3567 non-null   float64
#  9   Wait_Time_Score  3541 non-null   float64
#  10  Manner_Score     3541 non-null   float64
#  11  Doc_Urls         4000 non-null   object
# dtypes: bool(1), float64(5), int64(1), object(5)
# memory usage: 378.9+ KB

# %%
# check which rows has at least one nan values

#df[df.isna().any(axis = 1)]

# %%
df0
# Out:
#                                Level        Specialties  Gender Language  \
# Name
# Dr. Rita Aronov, MD                0  Pediatric Doctors  Female  English
# Dr. Tamir Danilov, DPM             0         Podiatrist    Male  English
# Dr. Demetrios Mihalos, DDS         0            Dentist    Male  English
# Dr. Chunpang (Tony) Shen, MD       0  Pediatric Doctors    Male  English
# Dr. Irina Mikheyeva, DO            0             OB-GYN  Female  English
# ...                              ...                ...     ...      ...
# Sedighe (Sedi) Flugelman, PhD      0       Psychologist  Female  English
# Melissa Johnson, PsyD              0       Psychologist  Female  English
# Dr. David Berkower, DDS            0            Dentist    Male  English
# Dr. Yekaterina Kuznetsova, DO      0     General Doctor  Female  English
# Rachel Freed, PhD                  0       Psychologist  Female  English
#
#                                Video_Visit      City  Zipcode  Total_Reviews  \
# Name
# Dr. Rita Aronov, MD                  False  Brooklyn  11201.0           88.0
# Dr. Tamir Danilov, DPM               False  New York  10002.0          148.0
# Dr. Demetrios Mihalos, DDS           False  New York  10065.0          400.0
# Dr. Chunpang (Tony) Shen, MD          True  New York      NaN           15.0
# Dr. Irina Mikheyeva, DO               True  Brooklyn  11223.0          261.0
# ...                                    ...       ...      ...            ...
# Sedighe (Sedi) Flugelman, PhD         True  New York  10022.0           22.0
# Melissa Johnson, PsyD                False  Brooklyn  11238.0            3.0
# Dr. David Berkower, DDS              False  New York  10128.0            3.0
# Dr. Yekaterina Kuznetsova, DO         True  New York  10016.0         1507.0
# Rachel Freed, PhD                    False  New York  10029.0            NaN
#
#                                Overall_Ratings  Wait_Time_Score  Manner_Score  \
# Name
# Dr. Rita Aronov, MD                       4.97             4.67          5.00
# Dr. Tamir Danilov, DPM                    4.89             4.53          4.90
# Dr. Demetrios Mihalos, DDS                4.93             4.79          4.94
# Dr. Chunpang (Tony) Shen, MD              4.67             3.53          4.87
# Dr. Irina Mikheyeva, DO                   4.25             3.07          4.40
# ...                                        ...              ...           ...
# Sedighe (Sedi) Flugelman, PhD             4.64             5.00          4.73
# Melissa Johnson, PsyD                     5.00             5.00          5.00
# Dr. David Berkower, DDS                   5.00             5.00          5.00
# Dr. Yekaterina Kuznetsova, DO             4.33             4.01          4.38
# Rachel Freed, PhD                          NaN              NaN           NaN
#
#                                                                         Doc_Urls
# Name
# Dr. Rita Aronov, MD            https://www.zocdoc.com/doctor/rita-aronov-md-5...
# Dr. Tamir Danilov, DPM         https://www.zocdoc.com/doctor/tamir-danilov-dp...
# Dr. Demetrios Mihalos, DDS     https://www.zocdoc.com/dentist/demetrios-mihal...
# Dr. Chunpang (Tony) Shen, MD   https://www.zocdoc.com/doctor/chunpang-tony-sh...
# Dr. Irina Mikheyeva, DO        https://www.zocdoc.com/doctor/irina-mikheyeva-...
# ...                                                                          ...
# Sedighe (Sedi) Flugelman, PhD  https://www.zocdoc.com/doctor/sedighe-sedi-flu...
# Melissa Johnson, PsyD          https://www.zocdoc.com/doctor/melissa-johnson-...
# Dr. David Berkower, DDS        https://www.zocdoc.com/dentist/david-berkower-...
# Dr. Yekaterina Kuznetsova, DO  https://www.zocdoc.com/doctor/yekaterina-kuzne...
# Rachel Freed, PhD              https://www.zocdoc.com/doctor/rachel-freed-phd...
#
# [4000 rows x 12 columns]

# %%
# Correlation between the values
pd.DataFrame(df0[['Video_Visit', 'Total_Reviews', 'Overall_Ratings', 'Wait_Time_Score', 'Manner_Score']].corr().unstack().sort_values(ascending = False))
# Out:
#                                         0
# Manner_Score    Manner_Score     1.000000
# Wait_Time_Score Wait_Time_Score  1.000000
# Total_Reviews   Total_Reviews    1.000000
# Overall_Ratings Overall_Ratings  1.000000
# Video_Visit     Video_Visit      1.000000
# Manner_Score    Overall_Ratings  0.883788
# Overall_Ratings Manner_Score     0.883788
# Manner_Score    Wait_Time_Score  0.543766
# Wait_Time_Score Manner_Score     0.543766
#                 Overall_Ratings  0.534944
# Overall_Ratings Wait_Time_Score  0.534944
# Video_Visit     Wait_Time_Score  0.098053
# Wait_Time_Score Video_Visit      0.098053
# Video_Visit     Total_Reviews    0.066225
# Total_Reviews   Video_Visit      0.066225
# Video_Visit     Manner_Score     0.059573
# Manner_Score    Video_Visit      0.059573
# Video_Visit     Overall_Ratings  0.059087
# Overall_Ratings Video_Visit      0.059087
# Total_Reviews   Overall_Ratings -0.088337
# Overall_Ratings Total_Reviews   -0.088337
# Total_Reviews   Manner_Score    -0.089450
# Manner_Score    Total_Reviews   -0.089450
# Total_Reviews   Wait_Time_Score -0.120748
# Wait_Time_Score Total_Reviews   -0.120748

# %%
fig1 = pd.DataFrame(df0.Gender.value_counts())
fig1
# Out:
#         Gender
# Male      2092
# Female    1908

# %%
fig1.plot.bar()
plt.ylabel('Count')
plt.show()

# %%
fig2 = pd.DataFrame(df0.Specialties.value_counts())
fig2
# Out:
#                     Specialties
# Dentist                     661
# Therapist                   541
# Surgeon                     241
# Internist                   213
# Eye Doctor                  205
# Other Specialist            194
# General Doctor              191
# OB-GYN                      183
# Podiatrist                  174
# Dermatologist               154
# Psychologist                149
# Chiropractor                134
# Gastroenterologist          108
# Psychiatrist                105
# Nurse Practitioner          103
# Pediatric Doctors            95
# Cardiologist                 85
# Neurologist                  58
# Allergist                    53
# Endocrinologist              52
# Urologist                    41
# Nutritionist                 41
# Physiatrist                  40
# Otolaryngologist             40
# Oncologist                   38
# Pulmonologist                19
# Anesthesiologist             17
# Audiologist                  16
# Nephrologist                 16
# Midwife                      12
# Rheumatologist                8
# Hepatologist                  4
# Hematologist                  4
# Radiologist                   4
# Proctologist                  1

# %%
fig2.plot.bar().set_title("Counts of Specialties of Doctors", fontsize = 15)
plt.xlabel('Specialties')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
fig3 = pd.DataFrame(df.Language.value_counts())
fig3[fig3['Language'] >= 8].drop(index = 'English')

## Languages with value 1 : ['Danish', 'Lithuanian', 'Tibetan', 'Kashmiri', 'American Sign Language',
#        'Xhosa', 'Romani', 'Afrikaans', 'Nepali', 'Amharic', 'Mongolian',
#        'Hausa', 'Norwegian', 'Latvian', 'Tajik', 'Bosnian', 'Yoruba', 'Zulu',
#        'Czech', 'Pashto', 'Assamese', 'Azerbaijani', 'Hiligaynon']


# English = 3972
# Out:
#                      Language
# Spanish                   929
# Russian                   373
# Chinese (Mandarin)        159
# French                    151
# Hebrew                    142
# Hindi                     115
# Chinese (Cantonese)       109
# Korean                     84
# Farsi                      71
# Italian                    62
# Arabic                     48
# Greek                      47
# Polish                     44
# Urdu                       42
# Gujarati                   32
# German                     32
# Ukrainian                  30
# Yiddish                    23
# Romanian                   23
# Tagalog                    22
# Portuguese                 21
# Punjabi                    21
# Bengali                    18
# Japanese                   16
# Creole (Haitian)           13
# Turkish                    11
# Chinese (Fujian)           11
# Filipino                   10
# Vietnamese                 10
# Georgian                    9
# Telugu                      9
# Taiwanese                   9

# %%
fig3[fig3['Language'] < 10]
# Out:
#                         Language
# Georgian                       9
# Telugu                         9
# Taiwanese                      9
# Armenian                       7
# Tamil                          6
# Uzbek                          6
# Chinese (Shanghainese)         5
# Burmese                        5
# Marathi                        5
# Dutch                          5
# Hungarian                      4
# Creole                         4
# Albanian                       4
# Thai                           3
# Slovak                         3
# Bulgarian                      3
# Swahili                        3
# Kannada                        3
# Sindhi                         2
# Malay                          2
# Chinese (Wenzhounese)          2
# Serbo-Croatian                 2
# Malayalam                      2
# Indonesian                     2
# Romani                         1
# Lithuanian                     1
# Tajik                          1
# Tibetan                        1
# American Sign Language         1
# Zulu                           1
# Xhosa                          1
# Azerbaijani                    1
# Nepali                         1
# Latvian                        1
# Czech                          1
# Hausa                          1
# Bosnian                        1
# Pashto                         1
# Afrikaans                      1
# Danish                         1
# Assamese                       1
# Amharic                        1
# Mongolian                      1
# Kashmiri                       1
# Norwegian                      1
# Hiligaynon                     1
# Yoruba                         1

# %%
plt.figure(figsize=(12,6))
fig3[fig3['Language'] >= 150].plot.bar().set_title('Top 5 Languages Spoken by Doctors', fontsize = 15)
plt.show()

# %%
fig3[(fig3['Language'] < 150 ) & (fig3['Language'] >= 8)].plot.bar().set_title('Languages Spoken by Doctors >= 8', fontsize = 15)
plt.show()

# %%
fig3[fig3['Language'] < 8].plot.bar().set_title('Languages Spoken by Doctors < 8', fontsize = 15)
plt.xlabel('Specialties')
plt.ylabel('Count')
plt.show()

# %%
fig4 = df0[['Specialties', 'Total_Reviews']].groupby('Specialties').sum().sort_values(by = 'Total_Reviews', ascending=False)
fig4
# Out:
#                     Total_Reviews
# Specialties
# Dentist                   85437.0
# Dermatologist             84645.0
# OB-GYN                    78250.0
# Internist                 73902.0
# General Doctor            51851.0
# Eye Doctor                45166.0
# Podiatrist                26314.0
# Gastroenterologist        25216.0
# Surgeon                   25026.0
# Otolaryngologist          16314.0
# Chiropractor              14457.0
# Therapist                 13088.0
# Other Specialist          12433.0
# Allergist                 12137.0
# Psychiatrist               9432.0
# Endocrinologist            7884.0
# Urologist                  6347.0
# Pediatric Doctors          5624.0
# Neurologist                5598.0
# Nurse Practitioner         5533.0
# Cardiologist               5110.0
# Pulmonologist              3499.0
# Psychologist               3153.0
# Physiatrist                2659.0
# Nutritionist               1561.0
# Anesthesiologist           1045.0
# Rheumatologist              779.0
# Midwife                     755.0
# Audiologist                 439.0
# Oncologist                  431.0
# Nephrologist                334.0
# Proctologist                218.0
# Radiologist                  82.0
# Hepatologist                 40.0
# Hematologist                  0.0

# %%
plt.figure(figsize=(10,6))
fig4.plot.bar().set_title('Sum of Total Reviews by Specialties', fontsize=15)
plt.xlabel('Specialties')
plt.ylabel('Count')
plt.show()
